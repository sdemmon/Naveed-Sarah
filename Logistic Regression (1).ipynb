# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('booksummaries.txt', sep='\t',
                 names=['id1', 'id2', 'title', 'author', 'year', 'genres', 'summary'],
                 usecols=[2, 3, 5, 6], converters={'genres' : lambda s : (list(json.loads(s).values()) if s else None)})

# %%
valid_genres = ['Science Fiction','Crime Fiction','Non-fiction','Children\'s literature',
                'Fantasy', 'Mystery', 'Young adult literature']

# %%
# Iterate through each row to extract and split the list of genres
book_list = []

# Iterate through each element in the 'genres_column'
for i, row in df.iterrows():
    if row["genres"]:
        for genre in valid_genres:
            new_row={
                "title": row["title"],
                "author": row["author"],
                "summary": row["summary"]
                }
            genre_list=row["genres"]
            if genre in genre_list:
                new_row["genre"]=genre
                book_list.append(new_row)
book_df = pd.DataFrame(book_list)

# %%
book_df = book_df.drop_duplicates(subset=['title'])

# %%
book_df
# Out:
#                                              title             author  \
# 0                                      Animal Farm      George Orwell
# 1                               A Clockwork Orange    Anthony Burgess
# 2                             A Fire Upon the Deep       Vernor Vinge
# 4                             A Wizard of Earthsea  Ursula K. Le Guin
# 6                  Blade Runner 3: Replicant Night        K. W. Jeter
# ...                                            ...                ...
# 10604  Nevermore: The Final Maximum Ride Adventure    James Patterson
# 10605                                       Heaven      V. C. Andrews
# 10606                                   Dark Angel      V. C. Andrews
# 10607                            Gates of Paradise      V. C. Andrews
# 10608                               The Third Lynx       Timothy Zahn
#
#                                                  summary  \
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The novel posits that space around the Milky ...
# 4       Ged is a young boy on Gont, one of the larger...
# 6       Living on Mars, Deckard is acting as a consul...
# ...                                                  ...
# 10604   The prologue is Angel's vision of Max's death...
# 10605   Heaven Leigh Casteel is a fourteen year old g...
# 10606   After the events of Heaven (the first book in...
# 10607   A novel about Annie Stonewall, the daughter o...
# 10608   The story starts with former government agent...
#
#                         genre
# 0       Children's literature
# 1             Science Fiction
# 2             Science Fiction
# 4       Children's literature
# 6             Science Fiction
# ...                       ...
# 10604  Young adult literature
# 10605  Young adult literature
# 10606  Young adult literature
# 10607  Young adult literature
# 10608         Science Fiction
#
# [7958 rows x 4 columns]

# %%
plt.figure(figsize=(10,5))
sns.set_theme(style='whitegrid')
sns.countplot(data=book_df, order=book_df["genre"].value_counts().index, y='genre')
plt.title("Counts per Genre")
plt.show()

# %%
#Calculate posts length
book_df["length_summary"] = book_df["summary"].apply(len)

#Create distribution plot
plt.figure(figsize=(12,8))
sns.distplot(book_df["length_summary"]).set_title("Length distribution")
# Out:
# Text(0.5, 1.0, 'Length distribution')

# %%
book_df.iloc[6]['summary']
# Out:
# ' Nine years after Emperor Paul Muad\'dib walked into the desert, blind, the ecological transformation of Dune has reached the point where some Fremen are living without stillsuits in the less arid climate and have started to move out of the Sietches and into the villages and cities. As the old ways erode, more and more pilgrims arrive to experience the planet of Muad\'dib. The Imperial high council has lost the political initiative and is powerless to control the Jihad. Paul\'s twin young children, Leto II and Ghanima, sharing his prescience, have concluded that their guardian Alia has succumbed to possession by one of her ancestors and fear that a similar fate awaits them. They (and Alia) also realize that the terraforming of Dune will kill all the sandworms, thus destroying the source of the spice. Leto also fears that, like his father, he will be trapped by his prescience. Possessed by the persona of her grandfather Baron Vladimir Harkonnen, Alia fears that her mother, about to return to Arrakis, will recognize her "abomination." A new religious figure called "The Preacher" has risen in the desert, railing against the religious government\'s injustices and the changes among the Fremen. Some Fremen believe he is Paul Atreides. The fallen House Corrino on Salusa Secundus plots to assassinate the twins and regain power. Lady Jessica returns to Arrakis and recognizes that her daughter has been possessed but finds no signs of abomination in the twins. She plans with them to thwart Alia\'s plotting. Leto arranges for Fremen leader Stilgar to protect his sister if there is an attempt on their lives. Alia attempts to assassinate Jessica who escapes into the desert with Duncan Idaho\'s help, precipitating a rebellion among the Fremen. The twins anticipate and survive the Corrino assassination plot. Leto leaves to seek out the Preacher while Ghanima, masking her memory with self-hypnosis, reports falsely that her brother had been murdered. Duncan and Jessica flee to Salusa Secundus where Jessica begins to mentor the Corrino heir Farad\'n. He seizes power from his regent mother and allies with the Bene Gesserit, who promise to marry him to Ghanima and support his bid for coronation as Emperor. A band of Fremen outlaws capture Leto and force him to undergo the spice trance at the suggestion of one of Alia\'s agents, who has infiltrated the group. His spice-induced visions show him a myriad of possible futures where humanity has become extinct and only one where humanity survives. He names this future "The Golden Path" and resolves to bring it to fruition. He escapes his captors and sacrifices his humanity in pursuit of the Golden Path. This requires him to physically fuse with a school of sandtrout, gaining superhuman strength and near-invulnerability. He travels across the desert and confronts the Preacher who does, in fact, prove to be his father, Paul Atreides. Duncan Idaho returns to Arrakis and provokes Stilgar into killing him. With Stilgar\'s neutrality now untenable, he seizes Ghanima and flees. Alia recaptures Ghanima and arranges her marriage to Farad\'n, planning to exploit the expected chaos when Ghanima kills him to avenge her brother\'s murder. The Preacher and Leto return to the capital to confront Alia who has the Preacher murdered, revealing his true identity. Leto reveals himself in a display of superhuman strength and triggers the return of Ghanima\'s genuine memories. He confronts Alia and offers to help her overcome her possession but she is overwhelmed by her ancestral personae and elects to commit suicide. Leto declares himself Emperor and asserts control over the Fremen. Farad\'n enlists in his service and delivers control of the Corrino armies. The seemingly immortal and omnipotent Leto is left as Emperor of the Known Universe, with Ghanima at his side.'

# %%
# test the bert model 
from transformers import DistilBertTokenizer
from transformers import TFDistilBertForSequenceClassification
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('stopwords')
stopw = stopwords.words('english')
# Out:
# 2024-04-19 15:58:10.831432: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sarahdemmon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Download stopwords from nltk
nltk.download('stopwords')
stop_words = list(stopwords.words('english'))

#Perform count vectorization
cv = CountVectorizer(analyzer="word", max_features=1000, strip_accents='ascii', stop_words=stop_words)

X_cnt = cv.fit_transform(book_df['summary'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sarahdemmon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Term Frequency Inverse transform
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

#Convert to numpy array
X_cnt.toarray()

#Tfidf object
tfizer = TfidfTransformer()

#Perform Tfid
X_tfidf = tfizer.fit_transform(X_cnt).toarray()

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

book_df['genre_enc'] = encoder.fit_transform(book_df['genre'])

#Get the labels
Y = book_df['genre_enc']

# %%
from sklearn.model_selection import train_test_split

#Create training / testing data split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, Y, test_size=0.2, random_state=7)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_model = LogisticRegression()

lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

#Confusion matrix and Classification Report
def perf_eval(y_true, y_pred):
    #Classification report
    print(classification_report(y_true, y_pred,
                                target_names=list(encoder.classes_)))
    #Calculate confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred)
    #Plot the figure
    plt.figure(figsize=(6, 6))
    sns.heatmap(conf_matrix,
                cmap='Blues',
                annot=True,
                fmt="d",
                xticklabels=list(encoder.classes_),
                yticklabels=list(encoder.classes_))
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.show()

# %%
perf_eval(y_test, lr_pred)
# Out:
#                         precision    recall  f1-score   support
#
#  Children's literature       0.57      0.71      0.63       355
#          Crime Fiction       0.60      0.56      0.58       139
#                Fantasy       0.55      0.47      0.50       261
#                Mystery       0.60      0.42      0.49       146
#            Non-fiction       0.80      0.29      0.43        41
#        Science Fiction       0.73      0.81      0.77       590
# Young adult literature       0.53      0.13      0.21        60
#
#               accuracy                           0.64      1592
#              macro avg       0.62      0.49      0.52      1592
#           weighted avg       0.63      0.64      0.62      1592

# %%
import joblib
from time import time
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
# [training duration, testing duration, Test Accuracy

benchmarks = {'NB' : [0.0, 0.0, 0.0],
              'NB_tuned':  [0.0, 0.0, 0.0],
              'SVC' :  [0.0, 0.0, 0.0],
              'SVC_tuned':  [0.0, 0.0, 0.0],
              'LR' :  [0.0, 0.0, 0.0],
              'LR_tuned':  [0.0, 0.0, 0.0],
                }

# %%
raw_documents = [str(doc) for doc in list(X_train)] # Convert elements to strings

# %%
#TfidfVectorizer(stop_words=stop_words, ngram_range=(1,3))
t0 = time()
LogReg_pipeline = Pipeline([
                ('tfidf', TfidfVectorizer(stop_words=stop_words, ngram_range=(1,1))),
                ('clf', OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=1)),
            ])
LogReg_pipeline.fit(X_train, y_train)
benchmarks['LR'][0] = (time() - t0)/60
#print("Training complete! Saving trained model....")
filename = "./LogReg_model.sav"
joblib.dump(LogReg_pipeline, filename)
print("Training took: {:.3f}[seconds] to complete and has been saved as {}".format(benchmarks['LR'][0],filename))
print("####Before tuning:####")
print('Train Accuracy : %.3f'%LogReg_pipeline.score(X_train, y_train))
print('Test Accuracy : %.3f'%LogReg_pipeline.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 7
#       2 t0 = time()
#       3 LogReg_pipeline = Pipeline([
#       4                 ('tfidf', TfidfVectorizer(stop_words=stop_words, ngram_range=(1,1))),
#       5                 ('clf', OneVsRestClassifier(LogisticRegression(solver='sag'), n_jobs=1)),
#       6             ])
# ----> 7 LogReg_pipeline.fit(X_train, y_train)
#       8 benchmarks['LR'][0] = (time() - t0)/60
#       9 #print("Training complete! Saving trained model....")
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
#     392 Fit all the transformers one after the other and transform the
#    (...)
#     413     Pipeline with fitted steps.
#     414 """
#     415 fit_params_steps = self._check_fit_params(**fit_params)
# --> 416 Xt = self._fit(X, y, **fit_params_steps)
#     417 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     418     if self._final_estimator != "passthrough":
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:370, in Pipeline._fit(self, X, y, **fit_params_steps)
#     368     cloned_transformer = clone(transformer)
#     369 # Fit or load from cache the current transformer
# --> 370 X, fitted_transformer = fit_transform_one_cached(
#     371     cloned_transformer,
#     372     X,
#     373     y,
#     374     None,
#     375     message_clsname="Pipeline",
#     376     message=self._log_message(step_idx),
#     377     **fit_params_steps[name],
#     378 )
#     379 # Replace the transformer of the step with the fitted
#     380 # transformer. This is necessary when loading the transformer
#     381 # from the cache.
#     382 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:349, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     348 def __call__(self, *args, **kwargs):
# --> 349     return self.func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:950, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     948 with _print_elapsed_time(message_clsname, message):
#     949     if hasattr(transformer, "fit_transform"):
# --> 950         res = transformer.fit_transform(X, y, **fit_params)
#     951     else:
#     952         res = transformer.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:2126, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2119 self._check_params()
#    2120 self._tfidf = TfidfTransformer(
#    2121     norm=self.norm,
#    2122     use_idf=self.use_idf,
#    2123     smooth_idf=self.smooth_idf,
#    2124     sublinear_tf=self.sublinear_tf,
#    2125 )
# -> 2126 X = super().fit_transform(raw_documents)
#    2127 self._tfidf.fit(X)
#    2128 # X is already a transformed view of raw_documents so
#    2129 # we set copy to False
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1383, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1375             warnings.warn(
#    1376                 "Upper case characters found in"
#    1377                 " vocabulary while 'lowercase'"
#    1378                 " is True. These entries will not"
#    1379                 " be matched with any documents"
#    1380             )
#    1381             break
# -> 1383 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1385 if self.binary:
#    1386     X.data.fill(1)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:1270, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1268 for doc in raw_documents:
#    1269     feature_counter = {}
# -> 1270     for feature in analyze(doc):
#    1271         try:
#    1272             feature_idx = vocabulary[feature]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:110, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     108 else:
#     109     if preprocessor is not None:
# --> 110         doc = preprocessor(doc)
#     111     if tokenizer is not None:
#     112         doc = tokenizer(doc)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:68, in _preprocess(doc, accent_function, lower)
#      49 """Chain together an optional series of text preprocessing steps to
#      50 apply to a document.
#      51
#    (...)
#      65     preprocessed string
#      66 """
#      67 if lower:
# ---> 68     doc = doc.lower()
#      69 if accent_function is not None:
#      70     doc = accent_function(doc)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'lower'
